# %%
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Akshara\Anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-2.0.0-pyh9f0ad1d_0
#
#
#
# ...
#
# geographiclib-1.50   | 34 KB     |            |   0%
# geographiclib-1.50   | 34 KB     | ####7      |  47%
# geographiclib-1.50   | 34 KB     | ########## | 100%
#
# ...

# %%
import geocoder # import geocoder

# initialize your variable to None
lat_lng_coords = None

# loop until you get the coordinates
while(lat_lng_coords is None):
  g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
  lat_lng_coords = g.latlng

latitude = lat_lng_coords[0]
longitude = lat_lng_coords[1]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-15d80b1bb123> in <module>
# ----> 1 import geocoder # import geocoder
#       2
#       3 # initialize your variable to None
#       4 lat_lng_coords = None
#       5
#
# ModuleNotFoundError: No module named 'geocoder'

# %% [markdown]
# ### Couldn't find the error so using CSV

# %%
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner

link = "http://cocl.us/Geospatial_data"
df1 = pd.read_csv(link)

df1.head(10)
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476
# 5         M1J  43.744734 -79.239476
# 6         M1K  43.727929 -79.262029
# 7         M1L  43.711112 -79.284577
# 8         M1M  43.716316 -79.239476
# 9         M1N  43.692657 -79.264848

# %%
df1.shape
# Out:
# (103, 3)

# %%
#changing column name to Postcode to merge two dataframe
df1.columns = ['Postcode','Latitude','Longitude']

cols = df1.columns.tolist()
cols
# Out:
# ['Postcode', 'Latitude', 'Longitude']

# %%
link = "https://raw.githubusercontent.com/YogeshTS/Coursera_Capstone/master/Week_3_Assignment/df_new.csv"
df = pd.read_csv(link,index_col=0)
df.head(10)
# Out:
#                                             Postcode Borough  \
# 0                                                NaN     NaN
# 1                                          Agincourt     M1S
# 2                             Alderwood, Long Branch     M8W
# 3    Bathurst Manor, Wilson Heights, Downsview North     M3H
# 4                                    Bayview Village     M2K
# 5                  Bedford Park, Lawrence Manor East     M5M
# 6                                        Berczy Park     M5E
# 7                        Birch Cliff, Cliffside West     M1N
# 8       Brockton, Parkdale Village, Exhibition Place     M6K
# 9  Business reply mail Processing Centre, South C...     M7Y
#
#            Neighbourhood
# 0  Canadian postal codes
# 1            Scarborough
# 2              Etobicoke
# 3             North York
# 4             North York
# 5             North York
# 6       Downtown Toronto
# 7            Scarborough
# 8           West Toronto
# 9           East Toronto

# %% [markdown]
# ### Merging two dataframe

# %%
df_new1 = pd.merge(df, df1, on='Postcode',how='outer')
df_new1.head(20)
# Out:
#                                              Postcode Borough  \
# 0                                                 NaN     NaN
# 1                                           Agincourt     M1S
# 2                              Alderwood, Long Branch     M8W
# 3     Bathurst Manor, Wilson Heights, Downsview North     M3H
# 4                                     Bayview Village     M2K
# 5                   Bedford Park, Lawrence Manor East     M5M
# 6                                         Berczy Park     M5E
# 7                         Birch Cliff, Cliffside West     M1N
# 8        Brockton, Parkdale Village, Exhibition Place     M6K
# 9   Business reply mail Processing Centre, South C...     M7Y
# 10  CN Tower, King and Spadina, Railway Lands, Har...     M5V
# 11                                Caledonia-Fairbanks     M6E
# 12              Canada Post Gateway Processing Centre     M7R
# 13                                          Cedarbrae     M1H
# ...

# %%
df1.columns
# Out:
# Index(['Postcode', 'Latitude', 'Longitude'], dtype='object')

# %%
df.columns
# Out:
# Index(['Postcode', 'Borough', 'Neighbourhood'], dtype='object')

# %%
df1['Postcode'] = df1['Postcode'].astype(str)

# %%
df['Postcode'] = df1['Postcode'].astype(str)

# %%
df_new = pd.merge(df, df1, on='Postcode',how='outer')
df_new.head(20)
# Out:
#    Postcode Borough          Neighbourhood   Latitude  Longitude
# 0       M1B     NaN  Canadian postal codes  43.806686 -79.194353
# 1       M1C     M1S            Scarborough  43.784535 -79.160497
# 2       M1E     M8W              Etobicoke  43.763573 -79.188711
# 3       M1G     M3H             North York  43.770992 -79.216917
# 4       M1H     M2K             North York  43.773136 -79.239476
# 5       M1J     M5M             North York  43.744734 -79.239476
# 6       M1K     M5E       Downtown Toronto  43.727929 -79.262029
# 7       M1L     M1N            Scarborough  43.711112 -79.284577
# 8       M1M     M6K           West Toronto  43.716316 -79.239476
# 9       M1N     M7Y           East Toronto  43.692657 -79.264848
# 10      M1P     M5V       Downtown Toronto  43.757410 -79.273304
# 11      M1R     M6E                   York  43.750072 -79.295849
# 12      M1S     M7R            Mississauga  43.794200 -79.262029
# ...
